# %% [markdown]
# #### Python Operators
#
# ##### Operators are special symbols that perform operations on variables and values.

# %% [markdown]
# <img src="../images/Operators-Full.jpeg" alt="" width="800" height="300"/>

# %% [markdown]
# ### Types of Python Operators
#
# #### Here's a list of different types of Python operators that we will learn in this tutorial.
#
# 1. Arithmetic Operators
# 2. Assignment Operators
# 3. Comparison Operators
# 4. Logical Operators
# 5. Membership operators
# 6. Identity Operators

# %% [markdown]
# <img src="../images/opearators.png" alt="" width="800" height="300"/>

# %% [markdown]
# #### 1. Python Arithmetic Operators
# ##### Arithmetic Operators: Arithmetic operators in Python allow you to perform basic mathematical operations such as addition, subtraction, multiplication, division, and more. They include:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Modulo (%)
# 6. Floor Division (//)
# 7. Exponentiation (**)

# %%
a = 6
b = 4

# addition
# print ('Sum: ', a + b)
# #
# # subtraction
# print ('Subtraction: ', a - b)
# #
# # multiplication
# print ('Multiplication: ', a * b)
# #
# # division
# print ('Division: ', a / b)
# #
# # floor division
# print ('Floor Division: ', a // b)
#
# print ('Modulo: ', a % b)
# #
# a to the power b
print ('Power: ', a ** b) # 6 * 6 * 6 * 6
# Out:
# Power:  1296

# %% [markdown]
# #### 2. Python Assignment Operators
#
# ##### Assignment Operators: Assignment operators are used to assign values to variables. They provide a concise way to update variable values based on computations. Examples of assignment operators in Python are:
#
# 1. Assignment (=)
# 2. Addition Assignment (+=)
# 3. Subtraction Assignment (-=)
# 4. Multiplication Assignment (*=)
# 5. Division Assignment (/=)
# 6. Modulo Assignment (%=)
# 7. Exponentiation Assignment (**=)
# 8. Floor Division Assignment (//=)

# %%
marks=20
marks += 10 #it is same as (marks= marks + 10)
marks-=10 #it is same as (marks= marks - 10)
marks/=2 #it is the same as (marks = marks/2)

# %% [markdown]
# #### 3. Python Comparison Operators
# ##### Comparison Operators: Comparison operators are used to compare two values and determine their relationship. They return a Boolean value (True or False) based on the comparison. Some common comparison operators in Python include:
# 1. Equal to (==)
# 2. Not equal to (!=)
# 3. Greater than (>)
# 4. Less than (<)
# 5. Greater than or equal to (>=)
# 6. Less than or equal to (<=)

# %%
a = 9
b = 7
# # equal to operator
# print('a == b =', a == b)
# #
# # # # not equal to operator
# print('a != b =', a != b)
# # #
# # # # greater than operator
# print('a > b =', a > b) # true
# # # #
# # # # # less than operator
# print('a < b =', a < b) # false
# #
# # # greater than or equal to operator
print('a >= b =', a >= b)
#
# # less than or equal to operator
print('a <= b =', a <= b)
# Out:
# a >= b = True
# a <= b = False

# %% [markdown]
# #### 4. Python Logical Operators
#
# ##### Logical Operators: Logical operators in Python are used to combine or manipulate Boolean values. They are particularly useful in controlling program flow and making decisions based on multiple conditions. The three logical operators in Python are:
# 1. Logical AND (and)
# 2. Logical OR (or)
# 3. Logical NOT (not)

# %%
# AND:Returns True only if both statements are true.

# print((5 > 3) and (10 > 20))

# OR:Returns True if at least one statement is true.

# print((5 > 10) or (10 < 20) or (6 > 20) or (12 > 600))
#
# # NOT: Reverses the result (inverts True to False and vice versa).
#
print(not (5 > 10))
# Out:
# True

# %% [markdown]
# #### 5. Membership operators
#
# Membership Operators: Membership operators are used to test whether a value belongs to a sequence or collection. They evaluate the presence of a value within a list, tuple, or string. Python provides two membership operators:
#
# - In Python, in and not in are the membership operators. They are used to test whether a value or variable is found in a sequence (`string`, `list`, `tuple`, `set` and `dictionary`).
# - In a `dictionary`, we can only test for the presence of a key, not the value.
#
# ##### Operators
#
# 1. In
# 2. Not In

# %%
sentence = "I born in Delhi"
word = "sahil"
# word in sentence

print(word in sentence)
# Out:
# False

# %%
new_sentence = "Pragra is teaching"
print("pragra" not in new_sentence)
# Out:
# True

# %%
name = "sahil"

print("a" in name)
# Out:
# True

# %% [markdown]
# #### 6. Identity Operators
#
# Identity Operators: Identity operators are used to compare the memory locations of two objects. They determine if two variables point to the same object in memory. Python has two identity operators:
#
# ##### Operators
# 1. Is
# 2. Is Not

# %%
name = "sahil" # ==

print(name is "sahil")
print(name == "sahil")

# print("rahul" is not "sahil")
# Out:
# True
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /var/folders/5m/y4g4395x1m9bbltrjdjn7hd00000gn/T/ipykernel_23784/2339393891.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   print(name is "sahil")
