# %% [markdown]
# #### Python Type Conversion
#
# ##### In programming, type conversion is the process of converting data of one type to another. For example: converting int data to str.
#
# There are two types of type conversion in Python.
#
# 1. Implicit Conversion - automatic type conversion
# 2. Explicit Conversion - manual type conversion

# %% [markdown]
# #### Python Implicit Type Conversion
# ##### In certain situations, Python automatically converts one data type to another. This is known as implicit type conversion.

# %% [markdown]
# ##### Example 1: Converting integer to float

# %%
integer_number = 123 # 123.0
float_number = 1.23 # 1.23

print("Data Type (Before addition) of integer_number:",type(integer_number))
print("Data Type of float_number:",type(float_number))


new_number = integer_number + float_number


# #
print("Data Type (After addition) of integer_number:",type(integer_number))
print("Data Type of float_number:",type(float_number))
#
# # display new value and resulting data type
print("Value:",new_number)
print("Data Type:",type(new_number))

# 124

# %% [markdown]
# #### Explicit Type Conversion
# - In Explicit Type Conversion, users convert the data type of an object to required data type.
# - We use the built-in functions like `int()`, `float()`, `str()`, etc to perform explicit type conversion.
# - This type of conversion is also called `typecasting` because the user casts (changes) the data type of the objects.

# %%
num_string = "12"
print("data type of num_string before typecasting:", type(num_string))
num_string = int(num_string)
print(num_string)
print("data type of num_string after typecasting:", type(num_string))
# Out:
# data type of num_string before typecasting: <class 'str'>
# 12
# data type of num_string after typecasting: <class 'int'>

# %%
myAge = 28
print(myAge)
print("Data type of myAge before typecasting:",type(myAge))

myAge = str(myAge)
print(myAge)
print("Data type of myAge before typecasting:",type(myAge))

# %%
name = "sahil"
print("Data type of myAge before typecasting:",type(name))

name = float(name)
print("Data type of myAge before typecasting:",type(name))

# %%
num_string = '12'
num_integer = 23 #num_integer : variable

print("Data type of num_string before Type Casting:",type(num_string))

# explicit type conversion
num_string = int(num_string)
#
print("Data type of num_string after Type Casting:",type(num_string))

num_sum = num_integer + num_string
#
print("Sum:",num_sum)
print("Data type of num_sum:",type(num_sum))

# %%
name = 845
age = 28

# %% [markdown]
# #### Coding Test
#
# 1. Create a variable called number1 = assign a string
# 2. Create another variable called number2 = assign an int
# 3. Performs type cast number1 --> multiplication and addition
# 4. Print both multiplication and addition

# %% [markdown]
# ### Key Points to Remember
# 1. Type Conversion is the conversion of an object from one data type to another data type.
# 2. Implicit Type Conversion is automatically performed by the Python interpreter.
# 3. Python avoids the loss of data in Implicit Type Conversion.
# 4. Explicit Type Conversion is also called Type Casting, the data types of objects are converted using predefined functions by the user.
# 5. In Type Casting, loss of data may occur as we enforce the object to a specific data type.
