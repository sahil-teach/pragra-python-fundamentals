# %% [markdown]
# #### Python Variables
# - In programming, a variable is a container (storage area) to hold data.

# %% [markdown]
# ##### Strings in Python

# %%
name = "sahil" # --> character - word - sentence (STRING) --> " quotes "
name = 'sahil' # --> character - word - sentence (STRING) --> ' quotes '

email = "1234@@@###sahil.com"

# %% [markdown]
# ##### Integer in Python

# %%
phoneNumber = 12345678 # INTEGER
age = 28
accountNumber = 1324323

# %% [markdown]
# ##### Float in Python

# %%
name = "harleen"

my_variable =
# Out:
# harleen

# %%
class = "sahil"

print(python)
# Out:
# sahil

# %%
height = 6.5 # FLOAT
weight = 78.9 # FLOAT

# %%
type(height)
# Out:
# float

# %% [markdown]
# ##### Boolean in Python

# %%
akshay_kumar = True
donald_trump = False

# %% [markdown]
# ##### Functions
# 1. Print
# 2. Type

# %%
print("Hello Pragra !!")
# Out:
# Hello Pragra !!

# %%
type()
# Out:
# str

# %%
yourNumber = 12345 # integers (int)

name = "sahil232@Q!!" # strings (str)  # 'sahil'

money = 12.12 # float

# %%
print(12.12)

# %%
# type

myAge = "28"

print(type(myAge))
# Out:
# <class 'str'>

# %%
# variable my football , ravi last name

myFootball = "adidas"
raviLastName = "kumar"
name = "ravi"


myfootball = "nike"

# %% [markdown]
# #### Assigning values to Variables in Python

# %%
# assign value to site_name variable
site_name = 'pragra.io'

print(site_name)
print(type(site_name))

# %% [markdown]
# #### Changing the Value of a Variable in Python

# %%
name = 'Sahil'
print("Your teacher name is :" ,name)

# assigning a new value to name

newName = "Sunny"
print(newName)
print("Your teacher name is :" ,newName)
print("Your teacher name is :" ,name)
# Out:
# Your teacher name is : Sahil
# Sunny
# Your teacher name is : Sunny
# Your teacher name is : Sahil

# %%
yourNumber = 12345

name = "sahil"

money = 12.12

# %%
yourNumber , name , money = 12345, "sahil" , 12.12

# %% [markdown]
# ### Coding Part
#
# 1. create a variable and store fav food.
# 2. create another variable and store your fav number
# 3. print both the variable

# %% [markdown]
# #### Assigning multiple values to multiple variables

# %%
myName, myAge, myHeight, myHome = 'Sahil', 28, 5.11, "Delhi"


myName = 'sahil' # string
myAge = 28 # int
myHeight = 5.11 # float
myHome = "Delhi" # string




# print(myName)
# print(myAge)
# print(myHeight)

# %% [markdown]
# ### Python Literals
# - Literals are representations of fixed values in a program. They can be numbers, characters, or strings, etc.
# - For example, `Hello, World!`, `12`, `23.0`, `C`, etc.

# %% [markdown]
# ### Python Numeric Literals
#
# #### Numeric Literals are immutable (unchangeable). Numeric literals can belong to 3 different numerical types: `Integer`, `Float`, and `Complex`.
#
# 1. Integer Literals : Integer literals are numbers without decimal parts. It also consists of negative numbers. For example, 5, -11, 0, 12, etc.
#
# 2. Floating-Point Literals : Floating-point literals are numbers that contain decimal parts. Just like integers, floating-point numbers can also be both positive and negative. For example, 2.5, 6.76, 0.0, -9.45, etc.
#
# ### Python String Literals
#
# #### In Python, texts wrapped inside quotation marks are called string literals.

# %% [markdown]
# ### Task:
# #### Write a Python program that:
# #### Stores your first name and last name in variables
# #### Joins them into a full name
# #### Stores your age in a variable
# ##### Prints: My name is <your name> and my age is <your age>

# %%
firstName = "sahil"
lastName = "nagpal"

fullName = firstName + " " + lastName
print(fullName)

age = 28
print(age)

print("My name is",fullName,"and my age is",age)
print("My name is " + fullName + " and my age is " + str(age))

# %%
# name : if variable is one word
# firstName or first_name : if variable has many words or more than one word --> first name firstname first name
# myAge
# myComputer

# %%
# name : if variable is one word
# myComputer <--> my_computer

# %%
name = "sahil"

age = 28


new_name = "Mamta"

print(name)
print(new_name)
# Out:
# sahil
# Mamta
